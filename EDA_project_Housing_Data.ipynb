# %% [markdown]
# # Exploratory Data Analysis
#  Import Laibrary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
#  # Readinng Dataset

# %%
df = pd.read_csv("housing_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# statistics summary of the data
df.describe()
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %% [markdown]
# # checking Missing value

# %%
# Total Nan value per columns and %

null_per_columns = df.isnull().sum()
print(null_per_columns[null_per_columns>0])
null_per_columns = (df.isnull().sum()/len(df))*100
print(null_per_columns[null_per_columns>0].round(2))
# Out:
# Alley          1369
# MasVnrType      872
# Electrical        1
# GarageYrBlt      81
# dtype: int64
# Alley          93.77
# MasVnrType     59.73
# Electrical      0.07
# GarageYrBlt     5.55
# dtype: float64

# %%
df.nunique()
# Out:
# Unnamed: 0       1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       111
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x='GarageType', data=df)
plt.xlabel('Type of Garage')     
plt.ylabel('Number of Houses')
plt.show()

# %% [markdown]
# # Most of the house havng attchd and detchd with the garagetype,so the the customer will preferd .It will impact the sale price of the houses.

# %%
sns.countplot(x = 'SaleType',data=df)
plt.xlabel('SaleType')     
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# # “Most houses  are sold through a regular warranty deed (WD), while other sale types like New, COD, or contract sales are much less common.The new home have highest sale price, while court and contract-based sales tend to have lower prices.

# %% [markdown]
# # pie chart

# %%
plt.figure(figsize=(6,6))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
plt.title('Garage Count Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# # “The majority of homes in the dataset have 2-car garages, making it the most common option, while 1-car and 3-car garages are also fairly common. Very few homes have no garage or extra-large garages.The price of the houses are mostly depend on garage space.

# %% [markdown]
# # Histogram

# %%
plt.hist(df['GarageArea'])
plt.show()

# %% [markdown]
# # “Most houses have medium-sized garages (200–600 sq ft), while very large garages or no garages are much less common.”

# %% [markdown]
# # Distplot

# %%
sns.distplot(df['SalePrice'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8844\405221552.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SalePrice'])

# %% [markdown]
# # “Most houses are sold at lower prices, and only a few are very expensive — the sale price distribution is right-skewed.”

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(df['GarageArea'])
plt.show()

# %% [markdown]
# # Most garages fall within a typical range.
# # There are some outliers,these are houses with very large garages, which are not common.
# # The median line inside the box tells you the most common garage size range.

# %% [markdown]
# # Multivariate

# %% [markdown]
# # Scatterplot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='GarageArea',
    y='SalePrice',
    hue='OverallQual',        
    size='GrLivArea',         
    data=df,
    palette='viridis',
    sizes=(20, 200),         
    alpha=0.7
)

plt.title('Sale Price vs Garage Area (Colored by Quality, Sized by Living Area)')
plt.xlabel('Garage Area (sq ft)')
plt.ylabel('Sale Price')
plt.legend(title='Overall Quality', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Positive Correlation between GarageArea and SalePrice, as Garage Area increases, Sale Price also increases.This means bigger garages are often part of more expensive homes .clusters of mid-priced homes with medium garage sizes. homes with very large garages but low prices shows the outliers means the property is unusable.
# # “There is a clear positive relationship between Garage Area and Sale Price. Houses with larger garages generally tend to be higher quality and have more above-ground living space. This indicates that garage size can be a useful indicator of overall property value.”

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x='BldgType',
    y='SalePrice',
    hue='SaleCondition',
    data=df,
    estimator=np.median,
    ci=None               
)

plt.title('Median Sale Price by Building Type and Sale Condition')
plt.xlabel('Building Type')
plt.ylabel('Median Sale Price')
plt.legend(title='Sale Condition', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8844\574402467.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # "Median Sale Prices are highest for single-family homes and lowest for duplexes and townhouses. Normal sale conditions consistently yield higher prices across all building types compared to abnormal or court-ordered sales."

# %% [markdown]
# # Box Plot

# %%
df_melted = df.melt(value_vars=['SalePrice', 'GrLivArea', 'LotArea', 'GarageArea'],
                    var_name='Feature', value_name='Value')

plt.figure(figsize=(12, 6))
sns.boxplot(x='Feature', y='Value', data=df_melted)
plt.title('Distribution of Key Features')
plt.show()

# %% [markdown]
# # “Lot size varies the most among houses, while garage size is usually similar. A few houses are much more expensive or larger than the rest.Most houses sell at moderate prices, but some high-value properties raise the overall price range — shown by the outliers in SalePrice.

# %% [markdown]
# # Heatmap

# %%
# Select numeric columns only
corr_df = df[['SalePrice', 'GrLivArea', 'LotArea', 'GarageArea', 'GarageCars', 'OverallQual']]
# Calculate correlation matrix

corr_matrix = corr_df.corr()
# Plot heatmap

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Key Housing Features')
plt.show()

# %% [markdown]
# # “SalePrice is most strongly influenced by Overall Quality and Living Area, while garage features matter moderately and lot size has little direct impact.”

# %% [markdown]
# # Distplot

# %%
# Lists of variables
numerical_cols = ['SalePrice', 'GrLivArea', 'LotArea', 'GarageArea']
categorical_cols = ['OverallQual', 'BldgType', 'Neighborhood', 'SaleCondition', 'HouseStyle']

for num_col in numerical_cols:
    for cat_col in categorical_cols:
        plt.figure(figsize=(10, 6))
        sns.kdeplot(data=df, x=num_col, hue=cat_col, fill=False, common_norm=False, palette='Set2', linewidth=2)
        plt.title(f'Distribution of {num_col} by {cat_col}')
        plt.xlabel(num_col)
        plt.ylabel('Density')
        plt.tight_layout()
        plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8844\2174869689.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x=num_col, hue=cat_col, fill=False, common_norm=False, palette='Set2', linewidth=2)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8844\2174869689.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df, x=num_col, hue=cat_col, fill=False, common_norm=False, palette='Set2', linewidth=2)

# %% [markdown]
# # Better quality homes (higher OverallQual) usually have higher prices.Their curves move to the right — meaning they cost more.
# # Bigger homes (more GrLivArea) are more common in certain house styles like 2Story. Some house styles are generally bigger than others.
# # Plot size (LotArea) depends on building type.Townhouses have small plots, single-family homes have bigger ones.
# # Garage size (GarageArea) increases with the number of cars it can hold (GarageCars).A 3-car garage has a bigger area than a 1-car garage — as expected.
# # SalePrice by Neighborhood shows that some areas have mostly expensive homes, while others are more affordable. Location really matters for house price.
# # Finally The plots clearly show that house price and size depend a lot on quality, building type, and neighborhood.

# %% [markdown]
# # Pairplot

# %%
pairplot_cols = ['SalePrice', 'GrLivArea', 'TotalLivingArea', 'GarageArea', 'OverallQual', 'LotArea']
sns.pairplot(df[pairplot_cols])
plt.show()

# %% [markdown]
# # Size (GrLivArea, TotalLivingArea) and Quality (OverallQual) have the strongest and clearest impact on house price.GarageArea has a moderate effect, while LotArea shows more variation and weaker correlation.

# %% [markdown]
# # Feature Engineering

# %%
df['TotalLivingArea'] = df['GrLivArea'] + df['TotalBsmtSF']
df['TotalArea'] = df['GrLivArea'] + df['TotalBsmtSF'] + df['GarageArea']

df['TotalBathrooms'] = df['FullBath'] + 0.5 * df['HalfBath']

df['BathPerBedroom'] = df['TotalBathrooms'] / df['BedroomAbvGr'].replace(0, np.nan)

df['AreaPerRoom'] = df['GrLivArea'] / df['TotRmsAbvGrd'].replace(0, np.nan)

df['Area_Quality'] = df['GrLivArea'] * df['OverallQual']

df['HasGarage'] = df['GarageArea'].apply(lambda x: 1 if x > 0 else 0)

df['PricePerSqFt'] = df['SalePrice'] / df['GrLivArea'].replace(0, np.nan)

df['LogSalePrice'] = np.log1p(df['SalePrice'])
df['LogGrLivArea'] = np.log1p(df['GrLivArea'])

# %% [markdown]
# # Check Correlation with SalePrice

# %%
important_cols = [
    'SalePrice', 'TotalLivingArea', 'TotalBathrooms', 'BathPerBedroom',
    'AreaPerRoom', 'Area_Quality', 'PricePerSqFt'
]

sns.heatmap(df[important_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation of Engineered Features with SalePrice")
plt.show()

# %% [markdown]
# # Size and quality together (Area_Quality and TotalLivingArea) are the strongest predictors of house price, while bathroom count and square-foot value also contribute meaningfully.

# %%
sns.scatterplot(x='TotalLivingArea', y='SalePrice', data=df)
plt.title('SalePrice vs TotalLivingArea')
plt.show()

sns.boxplot(x='HasGarage', y='SalePrice', data=df)
plt.title('SalePrice vs HasGarage')
plt.show()

# %% [markdown]
# # Both larger total living area and the presence of a garage are strong indicators of higher house prices, with TotalLivingArea showing a continuous positive trend and HasGarage creating a clear price gap.

# %% [markdown]
# # collectively contribute

# %%
# Fill NaNs with column median

X = df[['TotalLivingArea', 'TotalBathrooms', 'AreaPerRoom']].copy()
X = X.fillna(X.median())

y = df['SalePrice']

# Train the model
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

pd.Series(model.coef_, index=X.columns)
# Out:
# TotalLivingArea       56.145026
# TotalBathrooms     27126.168234
# AreaPerRoom          102.693755
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  

y = df['SalePrice']


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred = model.predict(X_test)

print("R² Score:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R² Score: 0.6954798898264574
# RMSE: 46187.20043927847

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual SalePrice")
plt.ylabel("Predicted SalePrice")
plt.title("Actual vs Predicted Prices")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.show()

# %% [markdown]
# # The house price mainly depends on the total living space and the number of bathrooms.Homes that are larger and have more bathrooms usually sell for a higher price.The feature AreaPerRoom (size of each room) adds some extra detail, but it doesn't strongly affect the price on its own.

# %% [markdown]
# # Market Trends and Historical Pricing
# # yearly Trend
# # This shows how average sale prices changed year by year.

# %%
price_by_year = df.groupby('YrSold')['SalePrice'].mean().reset_index()

sns.lineplot(x='YrSold', y='SalePrice', data=price_by_year, marker='o')
plt.title('Average House Sale Price by Year')
plt.xlabel('Year Sold')
plt.ylabel('Average Sale Price')
plt.grid(True)
plt.show()

# %% [markdown]
# # Month-Year Trend
# # House prices showed [increase/decrease/stability] over the years.Prices dropped around [2008–2009] likely due to the global financial crisis, and started recovering after [2009].This suggests that economic conditions significantly influence housing prices.

# %%
df['Month_Year'] = df['YrSold'].astype(str) + '-' + df['MoSold'].astype(str)

monthly_avg = df.groupby('Month_Year')['SalePrice'].mean().reset_index()

plt.figure(figsize=(12, 5))
sns.lineplot(x='Month_Year', y='SalePrice', data=monthly_avg, marker='o')
plt.xticks(rotation=45)
plt.title('Monthly Sale Price Trend')
plt.xlabel('Month-Year')
plt.ylabel('Average Sale Price')
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df, x='YrSold', y='SalePrice', hue='Neighborhood', ci=None)
plt.title('Sale Price Trend by Neighborhood')
plt.ylabel('Average Sale Price')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8844\3895629371.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df, x='YrSold', y='SalePrice', hue='Neighborhood', ci=None)

# %% [markdown]
# # house prices have changed over the years in different neighborhoods.Some neighborhoods consistently have higher prices than others, showing that location plays a big role in property value.

# %% [markdown]
# # . Customer Preferences and Amenities

# %% [markdown]
# # Boxplots for Categorical Amenities :-
# # Kitchen quality, basement quality, and garage finish have the strongest impact on house prices, while heating and central air contribute modestly.

# %%
sns.boxplot(x='KitchenQual', y='SalePrice', data=df)
plt.title("Sale Price vs Kitchen Quality")
plt.show()
sns.boxplot(x='BsmtQual', y='SalePrice', data=df)
plt.title("Sale Price vs BsmtQual")
plt.show()
sns.boxplot(x='GarageFinish', y='SalePrice', data=df)
plt.title("Sale Price vs GarageFinish")
plt.show()
sns.boxplot(x='HeatingQC', y='SalePrice', data=df)
plt.title("Sale Price vs HeatingQC")
plt.show()
sns.boxplot(x='CentralAir', y='SalePrice', data=df)
plt.title("Sale Price vs CentralAir ")
plt.show()

# %% [markdown]
# # Countplots for Customer Preferences:-
# #  Houses with at least one fireplace usually sell for more than houses without a fireplace.This means fireplaces add value and are preferred by buyers.

# %%
sns.countplot(x='Fireplaces', data=df)
plt.title("How Many Fireplaces Do Buyers Prefer?")
plt.show()
sns.barplot(x='Fireplaces', y='SalePrice', data=df, estimator=np.mean)
plt.title("Sale Price by Number of Fireplaces")
plt.show()

# %% [markdown]
# # Correlation with SalePrice:-
# # The heatmap shows that Kitchen Quality and Fireplaces have a strong positive correlation with SalePrice.Basement and heating quality also have moderate influence. Pool area has a small effect, likely due to its rarity.

# %%
quality_map = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1}
df['KitchenQual_Num'] = df['KitchenQual'].map(quality_map)
df['BsmtQual_Num'] = df['BsmtQual'].map(quality_map)
df['HeatingQC_Num'] = df['HeatingQC'].map(quality_map)
df[['KitchenQual_Num', 'BsmtQual_Num', 'HeatingQC_Num']] = df[['KitchenQual_Num', 'BsmtQual_Num', 'HeatingQC_Num']].fillna(0)
corr_cols = ['SalePrice', 'KitchenQual_Num', 'BsmtQual_Num', 'HeatingQC_Num', 'Fireplaces', 'PoolArea']
sns.heatmap(df[corr_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Amenity Correlation with Sale Price")
plt.show()

# %% [markdown]
# # Among all the amenities, kitchen quality (KitchenQual_Num) has the strongest impact on house prices.Fireplaces and basement quality also contribute noticeably to the price.Pool area and heating quality have less influence, meaning they don’t affect price as much in most cases.

# %%
from sklearn.ensemble import RandomForestRegressor
X = df[['KitchenQual_Num', 'BsmtQual_Num', 'HeatingQC_Num', 'Fireplaces', 'PoolArea']].fillna(0)
y = df['SalePrice']

model = RandomForestRegressor()
model.fit(X, y)

importances = pd.Series(model.feature_importances_, index=X.columns)
importances.sort_values().plot(kind='barh')
plt.title("Feature Importance: Amenities Impacting Price")
plt.show()

# %% [markdown]
# # Conclusion :- Customers are willing to pay more for homes with better kitchen and basement quality, fireplaces, and pools.Among these, kitchen quality and number of fireplaces show the strongest positive effect on price.Features like central air conditioning or garage finish also influence preference but to a lesser extent.
